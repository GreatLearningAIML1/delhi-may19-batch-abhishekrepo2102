# %% [markdown]
# # Project 2
#
#
# Questions
# Find the mean of old scheme and new scheme column. (5 points)
# Use the five percent significance test over the data to determine the p value to check new scheme has significantly raised outputs? (10 points)
# What conclusion does the test (p-value) lead to? (2.5 points)
# Suppose it has been calculated that in order for Titan to break even, the average output must increase by £5000 in the scheme compared to the old scheme. If this figure is alternative hypothesis, what is:
#         a) The probability of a type 1 error? (2.5 points)
#
#         b) What is the p- value of the hypothesis test if we test for a difference of $5000? (10 points)
#
#         c) Power of the test (5 points)

# %%
import numpy as np
import pandas as pd
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro
from statsmodels.stats.power import ttest_power

# %%
sales_df = pd.read_csv("C:/Users/Abhishek/Desktop/Salesforce.csv")

# %%
sales_df.head(10)
# Out:
#    SALESPERSON  Old_Scheme  New_Scheme
# 0            1          57          62
# 1            2         103         122
# 2            3          59          54
# 3            4          75          82
# 4            5          84          84
# 5            6          73          86
# 6            7          35          32
# 7            8         110         104
# 8            9          44          38
# 9           10          82         107

# %%
data1 = sales_df['Old_Scheme'].mean()

# %%
data2 = sales_df['New_Scheme'].mean()

# %%
t_statistic, p_value = ttest_ind(sales_df['Old_Scheme'], sales_df['New_Scheme'])
print(t_statistic, p_value)
# Out:
# -1.5608402120078468 0.12400179998875209

# %%
print ("two-sample t-test p-value=", p_value)
# Out:
# two-sample t-test p-value= 0.49063515686248105

# %% [markdown]
# # Since p value is greater than alpha (0.05) i.e. Accept null hypothesis that the means are equal

# %%
# values are in thousands so adding 5 in New scheme

sales_df.New_Scheme = sales_df.New_Scheme.add(5)

# %%
sales_df
# Out:
#     SALESPERSON  Old_Scheme  New_Scheme
# 0             1          57          67
# 1             2         103         127
# 2             3          59          59
# 3             4          75          87
# 4             5          84          89
# 5             6          73          91
# 6             7          35          37
# 7             8         110         109
# 8             9          44          43
# 9            10          82         112
# 10           11          67          89
# 11           12          64          90
# 12           13          78         104
# 13           14          53          44
# 14           15          41          39
# 15           16          39          63
# 16           17          80          78
# 17           18          87          58
# 18           19          73          71
# 19           20          65          83
# 20           21          28          46
# 21           22          62          76
# ...

# %%
t_statistic, p_value = ttest_ind(sales_df['Old_Scheme'], sales_df['New_Scheme'])
print(t_statistic, p_value)
# Out:
# -2.4279736631233173 0.018306880480459746

# %%
#power of the test

# %%
Zstats = (5)/np.std(sales_df['New_Scheme'])
ttest_power(Zstats,nobs=len(np.array(sales_df['New_Scheme']))-1,alpha=0.05,alternative='larger')
# Out:
# 0.29660245254588957

# %%
# Out:
# 68.03333333333333

# %%
# Out:
# 33.98457692410029
